# %% [markdown]
# # 1.Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 2.Import dataset from the given address and assing it to a variable called df

# %%
url='https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv'
df=pd.read_csv(url)

# %% [markdown]
# # print df

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %% [markdown]
# # 4.For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
df1=df.loc[ : ,"school":'guardian']

# %% [markdown]
# # print df1

# %%
df1
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %% [markdown]
# # 5.create a lambda function that capitalize strings

# %%
cpl=(lambda x: x.capitalize())

# %%
cpl
# Out:
# <function __main__.<lambda>(x)>

# %% [markdown]
# # 6.capitalize both Mjob and Fjob

# %%
Mj=df1["Mjob"].apply(cpl)

# %%
Mj
# Out:
# 0       At_home
# 1       At_home
# 2       At_home
# 3        Health
# 4         Other
# 5      Services
# 6         Other
# 7         Other
# 8      Services
# 9         Other
# 10      Teacher
# 11     Services
# 12       Health
# 13      Teacher
# 14        Other
# 15       Health
# 16     Services
# 17        Other
# 18     Services
# 19       Health
# 20      Teacher
# 21       Health
# 22      Teacher
# 23        Other
# 24     Services
# 25     Services
# 26        Other
# 27       Health
# 28     Services
# 29      Teacher
#          ...
# 365     At_home
# 366     Teacher
# 367       Other
# 368     At_home
# 369       Other
# 370    Services
# 371     At_home
# 372       Other
# 373       Other
# 374       Other
# 375       Other
# 376      Health
# 377     Teacher
# 378       Other
# 379     At_home
# 380     Teacher
# 381       Other
# 382       Other
# 383       Other
# 384       Other
# 385     At_home
# 386     Teacher
# 387    Services
# 388     Teacher
# ...

# %%
Fj=df1["Fjob"].apply(cpl)

# %%
Fj
# Out:
# 0       Teacher
# 1         Other
# 2         Other
# 3      Services
# 4         Other
# 5         Other
# 6         Other
# 7       Teacher
# 8         Other
# 9         Other
# 10       Health
# 11        Other
# 12     Services
# 13        Other
# 14        Other
# 15        Other
# 16     Services
# 17        Other
# 18     Services
# 19        Other
# 20        Other
# 21       Health
# 22        Other
# 23        Other
# 24       Health
# 25     Services
# 26        Other
# 27     Services
# 28        Other
# 29      Teacher
#          ...
# 365       Other
# 366    Services
# 367    Services
# 368    Services
# 369     Teacher
# 370    Services
# 371    Services
# 372     At_home
# 373       Other
# 374       Other
# 375       Other
# 376       Other
# 377    Services
# 378       Other
# 379       Other
# 380     Teacher
# 381       Other
# 382    Services
# 383    Services
# 384       Other
# 385       Other
# 386     At_home
# 387       Other
# 388    Services
# ...

# %% [markdown]
# # 7.print the last element of dataset

# %%
df1.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      reason guardian
# 390  course    other
# 391  course   mother
# 392  course    other
# 393  course   mother
# 394  course   father

# %%
df1.head(20)
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0      GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1      GP   F   17       U     GT3       T     1     1   at_home     other
# 2      GP   F   15       U     LE3       T     1     1   at_home     other
# 3      GP   F   15       U     GT3       T     4     2    health  services
# 4      GP   F   16       U     GT3       T     3     3     other     other
# 5      GP   M   16       U     LE3       T     4     3  services     other
# 6      GP   M   16       U     LE3       T     2     2     other     other
# 7      GP   F   17       U     GT3       A     4     4     other   teacher
# 8      GP   M   15       U     LE3       A     3     2  services     other
# 9      GP   M   15       U     GT3       T     3     4     other     other
# 10     GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %% [markdown]
# # 8.Did you notice the original dataframe is still lowercase? Why is that? Fix it and capitalize Mjob and Fjob.

# %%
df1[10:21]
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 10     GP   F   15       U     GT3       T     4     4   teacher    health
# 11     GP   F   15       U     GT3       T     2     1  services     other
# 12     GP   M   15       U     LE3       T     4     4    health  services
# 13     GP   M   15       U     GT3       T     4     3   teacher     other
# 14     GP   M   15       U     GT3       A     2     2     other     other
# 15     GP   F   16       U     GT3       T     4     4    health     other
# 16     GP   F   16       U     GT3       T     4     4  services  services
# 17     GP   F   16       U     GT3       T     3     3     other     other
# 18     GP   M   17       U     GT3       T     3     2  services  services
# 19     GP   M   16       U     LE3       T     4     3    health     other
# 20     GP   M   15       U     GT3       T     4     3   teacher     other
#
#         reason guardian
# 10  reputation   mother
# ...

# %%
df1["Mjob"]=df["Mjob"].apply(cpl)

# %%
df1["Fjob"]=df["Fjob"].apply(cpl)

# %%
df1
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   At_home   Teacher
# 1       GP   F   17       U     GT3       T     1     1   At_home     Other
# 2       GP   F   15       U     LE3       T     1     1   At_home     Other
# 3       GP   F   15       U     GT3       T     4     2    Health  Services
# 4       GP   F   16       U     GT3       T     3     3     Other     Other
# 5       GP   M   16       U     LE3       T     4     3  Services     Other
# 6       GP   M   16       U     LE3       T     2     2     Other     Other
# 7       GP   F   17       U     GT3       A     4     4     Other   Teacher
# 8       GP   M   15       U     LE3       A     3     2  Services     Other
# 9       GP   M   15       U     GT3       T     3     4     Other     Other
# 10      GP   F   15       U     GT3       T     4     4   Teacher    Health
# ...

# %% [markdown]
# # 9.Create a function called majority that return a boolean value to a new column called legal_drinker (Consider majority as older than 17 years old).

# %%
def majority(x):
    if x>17 :
        return True
    else:
        return False

# %%
df1["legal_drunker"]=df['age'].apply(majority)

# %%
df1
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   At_home   Teacher
# 1       GP   F   17       U     GT3       T     1     1   At_home     Other
# 2       GP   F   15       U     LE3       T     1     1   At_home     Other
# 3       GP   F   15       U     GT3       T     4     2    Health  Services
# 4       GP   F   16       U     GT3       T     3     3     Other     Other
# 5       GP   M   16       U     LE3       T     4     3  Services     Other
# 6       GP   M   16       U     LE3       T     2     2     Other     Other
# 7       GP   F   17       U     GT3       A     4     4     Other   Teacher
# 8       GP   M   15       U     LE3       A     3     2  Services     Other
# 9       GP   M   15       U     GT3       T     3     4     Other     Other
# 10      GP   F   15       U     GT3       T     4     4   Teacher    Health
# ...

# %% [markdown]
# # 10.Multiply every number of the dataset by 10.

# %%
def ten(x):
    if type(x) is int:
        return 10*x
    return x

# %%
df1.apply(ten)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   At_home   Teacher
# 1       GP   F   17       U     GT3       T     1     1   At_home     Other
# 2       GP   F   15       U     LE3       T     1     1   At_home     Other
# 3       GP   F   15       U     GT3       T     4     2    Health  Services
# 4       GP   F   16       U     GT3       T     3     3     Other     Other
# 5       GP   M   16       U     LE3       T     4     3  Services     Other
# 6       GP   M   16       U     LE3       T     2     2     Other     Other
# 7       GP   F   17       U     GT3       A     4     4     Other   Teacher
# 8       GP   M   15       U     LE3       A     3     2  Services     Other
# 9       GP   M   15       U     GT3       T     3     4     Other     Other
# 10      GP   F   15       U     GT3       T     4     4   Teacher    Health
# ...

# %%
df1
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   At_home   Teacher
# 1       GP   F   17       U     GT3       T     1     1   At_home     Other
# 2       GP   F   15       U     LE3       T     1     1   At_home     Other
# 3       GP   F   15       U     GT3       T     4     2    Health  Services
# 4       GP   F   16       U     GT3       T     3     3     Other     Other
# 5       GP   M   16       U     LE3       T     4     3  Services     Other
# 6       GP   M   16       U     LE3       T     2     2     Other     Other
# 7       GP   F   17       U     GT3       A     4     4     Other   Teacher
# 8       GP   M   15       U     LE3       A     3     2  Services     Other
# 9       GP   M   15       U     GT3       T     3     4     Other     Other
# 10      GP   F   15       U     GT3       T     4     4   Teacher    Health
# ...

# %%
df1.plot()
